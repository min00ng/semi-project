# %%
from NewsAnalyzer.PreProcesser import preprocesser

file_path = "data/2022-04-12 news data, test.csv"

pc = preprocesser()
df = pc.road_data(file_path)
df
# Out:
#      카테고리     언론사                                            기사제목  \
# 0      정치  디지털타임스  김준일 대표, ‘검수완박’ 민주당에 쓴소리…“‘논리적 확증편향’ 빠졌는지 돌아봐야”
# 1      정치    중앙일보              [단독]윤희숙 父 ‘투기의혹’ 세종시 땅 매각…차익 전액 기부
# 2      정치    문화일보                      전쟁 피해 절박한 젤렌스키… 미지근한 한국 국회
# 3      정치   아시아경제          금태섭 "文 정권 땐 특수부 키우더니 이젠 검수완박…이러니 내로남불"
# 4      정치     머니S                송영길 "애도 아니고 5선 정치인 진퇴가 가벼울 수 없다"
# ...   ...     ...                                             ...
# 1042   세계    한국일보                   친(親)러 도네츠크 군, “우크라 마리우폴 항 장악”
# 1043   세계     YTN                    러시아군 물러났지만...현실화된 우크라발 식량 위기
# 1044   세계     뉴스1                   우크라 內 친러 도네츠크 군대 "마리우폴 장악 임박"
# 1045   세계    연합뉴스             은혜 갚은 빈살만?…사우디 국부펀드, 쿠슈너에 2조5천억원 투자
# 1046   세계    중앙일보                마크롱, 우크라 올인한 사이…르펜, 먹고사는 문제로 맹추격
#
#                날짜                                                 본문
# 0     2022.04.12.  \r\n\r\n\r\n\r\n\r\n‘계곡 살인’ 이은해 사건 거론하며 “‘검수완박...
# ...

# %%
title = df["본문"]
title
# Out:
# 0       \r\n\r\n\r\n\r\n\r\n‘계곡 살인’ 이은해 사건 거론하며 “‘검수완박...
# 1       \r\n\r\n\r\n\r\n\r\n  지난해 8월 25일 국민권익위원회 조사에서 ...
# 2       \r\n\r\n\r\n\r\n\r\n젤렌스키 우크라 대통령, “무기 요청” 국회 화...
# 3       \r\n\r\n\r\n\r\n\r\n"응징적 차원에서 제도 바꾸면 중립성 해칠 것"...
# 4       \r\n\r\n\r\n\r\n\r\n송영길 더불어민주당 전 대표가 12일 민주당의 ...
#                               ...
# 1042    \r\n\r\n\r\n\r\n\r\n우크라군, 항만시설ㆍ제철소에서 마지막 저항중 마...
# 1043    \r\n\r\n\r\n\r\n동영상 뉴스\r\n\r\n\r\n\r\n\r\n\t\r...
# 1044    \r\n\r\n\r\n\r\n\r\n우크라군 이미 몰려 있어…DPR군 전투 강화할 ...
# 1045    \r\n\r\n\r\n\r\n\r\nNYT 보도…자문단 반대에도 경험 없는 쿠슈너 ...
# 1046    \r\n\r\n\r\n\r\n\r\n\t\r\n\t  중도 성향의 에마뉘엘 마크롱 ...
# Name: 본문, Length: 1046, dtype: object

# %%
title = df.본문[5]

# %%
import re
def clean_text(title):
    text_rmv = re.sub('[-=+,#/\?:^.@*\"※%~∼ㆍ!【】』㈜©囹圄秋 ■◆◇▷▶◁◀ △▲▽▼<>‘|\(\)\[\]`\'…》→←↑↓↔〓♤♠♡♥♧♣⊙◈▣◐◑☆★\”\“\’·※~ ! @ # $ % ^ & * \ " ]', ' ', title)
    text_rmv = ' '.join(text_rmv.split())
    return text_rmv

# %%
from kiwipiepy import Kiwi, Match
kiwi = Kiwi()
sentence = clean_text(title)
result_iter = kiwi.tokenize(sentence, normalize_coda=True)
result_iter[0:2]
result_iter[0]
result_iter[0][1]
# Out:
# 'SL'

# %%
title = df.본문[5]
clean_text(title)
sentence = clean_text(title)

# %%
from kiwipiepy import Kiwi, Match
from kiwipiepy.utils import Stopwords


def stop_words_list(self):
    stopwords = Stopwords()
    stopwords.add(('자료', 'NNG'))
    stopwords.add(('사진', 'NNG'))
    stopwords.add(('기자', 'NNG'))
    stopwords.add(('동영상', 'NNG'))
    stopwords.add(('이미지', 'NNG'))
    stopwords.add(('출처', 'NNG'))
    stopwords.add(('뉴스', 'NNG'))
    stopwords.add(('카카오톡', 'NNG'))
    stopwords.add(('news', 'SL'))
    stopwords.add(('co', 'SL'))
    stopwords.add(('kr', 'SL'))
    stopwords.add(('org', 'SL'))
    stopwords.add(('naver', 'SL'))
    stopwords.add(('kmib', 'SL'))
    stopwords.add(('CBS', 'SL'))
    stopwords.add(('yna', 'SL'))
    stopwords.add(('yna', 'SL'))
    return stopwords

# %%
print(stop_words_list(self))

# %% [markdown]
# sentence = clean_text(title)
# noun_extractor(sentence)

# %%
from kiwipiepy.utils import Stopwords
stopwords = Stopwords()
[stopwords.add(('사진', 'NNG'),
stopwords.add(('동영상', 'NNG'),
stopwords.add(('이미지', 'NNG'),
stopwords.add(('출처', 'NNG'),
stopwords.add(('뉴스', 'NNG'),
stopwords.add(('카카오톡', 'NNG'),
stopwords.add('news', 'SL')
# Out:
#   File "C:\Users\서지혜\AppData\Local\Temp/ipykernel_22648/1286406520.py", line 9
#     stopwords.add('news', 'SL')
#                                ^
# SyntaxError: unexpected EOF while parsing

# %%
from kiwipiepy.utils import Stopwords
stopwords = Stopwords()
print(Stopwords)
# Out:
# <class 'kiwipiepy.utils.Stopwords'>

# %%
from kiwipiepy.utils import Stopwords

def stop_words_list(self):
    stopwords = Stopwords()
    stopwords.add(('단독', 'NNG'))
    stopwords.add(('자료', 'NNG'))
    stopwords.add(('사진', 'NNG'))
    stopwords.add(('기자', 'NNG'))
    stopwords.add(('동영상', 'NNG'))
    stopwords.add(('이미지', 'NNG'))
    stopwords.add(('출처', 'NNG'))
    stopwords.add(('뉴스', 'NNG'))
    stopwords.add(('카카오톡', 'NNG'))
    stopwords.add(('news', 'SL'))
    stopwords.add(('co', 'SL'))
    stopwords.add(('kr', 'SL'))
    stopwords.add(('org', 'SL'))
    stopwords.add(('naver', 'SL'))
    stopwords.add(('kmib', 'SL'))
    stopwords.add(('CBS', 'SL'))
    stopwords.add(('yna', 'SL'))
    return stopwords

# %%
print(stop_words_list(self))

# %%
sentence = clean_text(title)
noun_extractor(sentence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22648/2124336207.py in <module>
#       1 sentence = clean_text(title)
# ----> 2 noun_extractor(sentence)
#
# TypeError: noun_extractor() missing 1 required positional argument: 'sentence'

# %%
clean_text(title)
# Out:
# used default noun predictor; Sejong corpus based logistic predictor
# C:/ProgramData/Anaconda3/lib/site-packages/soynlp
# local variable 'f' referenced before assignment
# local variable 'f' referenced before assignment
# scan vocabulary ...
# done (Lset, Rset, Eojeol) = (278, 0, 278)
# predicting noun score was done
# before postprocessing 0
# _noun_scores_ 0
# checking hardrules ... doneNsubJ (떡볶+(이)), NVsubE (사기(당)+했다) ... done
# after postprocessing 0
# extracted 0 compounds from eojeols
# {}

# %%
title = df.본문[1040]
clean_text(title)
# Out:
# '바이든 모디 정상회담 러시아 문제 논의외교 국방 2 2 회담도 美 印 설득 모양새군사협력 비동맹외교 전통 인도 변수 난제조 바이든 오른쪽 미국 대통령이 지난해 9월 24일 워싱턴 백악관 집무실에서 나렌드라 모디 인도 총리와 정상회담을 하고 있다 워싱턴 AP 연합뉴스조 바이든 미국 대통령이 11일 현지시간 나렌드라 모디 인도 총리와 화상 정상회담을 했다 미국과 인도는 외교 국방장관 2 2 회담도 개최했다 러시아의 우크라이나 침공 후 러시아 제재에 동참하지 않고 중립을 표방하는 인도를 미국이 설득하는 모양새다 하지만 러시아와 미국 모두를 잃지 않겠다는 인도의 원칙 때문에 회담 전망은 그리 밝지 않았다 바이든 대통령은 이날 워싱턴 백악관에서 모디 총리와 화상으로 정상회담을 진행했다 지난달 3일 열린 쿼드 Quad 화상 정상회의에서 일본 호주 총리와 함께 만난 지 한 달여 만이다 미 백악관은 회의에 앞서 두 정상이 신종 코로나바이러스 감염증 코로나19 종식 기후위기 대응 글로벌 경제 강화 인도태평양경제프레임워크 IPEF 등을 논의할 것이라고 설명했다 특히 바이든 대통령이 러시아의 잔혹한 우크라이나 전쟁 결과 세계 식량 및 상품 시장에 미치는 불안정성 경감 방안 등을 긴밀히 협의할 것 이라고 젠 사키 백악관 대변인이 10일 밝혔다 또 정상회담 직후 미국 토니 블링컨 국무 로이드 오스틴 국방장관이 인도의 S 자이샨카르 외교 라자 낫 싱 국방장관과 워싱턴 국무부에서 2 2 회담을 열었다 바이든 행정부 출범 후 미국 인도관계는 끈끈했다 중국 견제라는 한뜻으로 뭉쳐 쿼드 정상회의는 물론 양자 정상회담을 하며 협력 수위를 높였다 그러나 지난 2월 러시아의 우크라이나 침공 후 중립을 강조하는 인도가 미국과 서방의 러시아 제재망에 구멍 이 되고 있다 우크라이나 침공 와중에 인도를 방문한 세르게이 라브로프 왼쪽 러시아 외무장관이 지난 1일 수도 뉴델리에서 S 자이샨카르 인도 외교장관과 만나 회담 전 기념사진 촬영을 하고 있다 뉴델리 EPA 연합뉴스인도는 최근 열린 유엔 안전보장
# ...

# %%
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# 문서 단위 말뭉치 생성 
corpus = DoublespaceLineCorpus("/content/4.12 news data.csv")
#앞 5개 문서 인쇄
i = 0
for d in corpus:
    print(i, d)
    i += 1
    if i > 4:
        break

word_extractor = WordExtractor()
word_extractor.train(corpus)
word_score = word_extractor.extract()

#잘되는지 확인해보기
word_score["검수완박"].cohesion_forward
word_score["우크라"].cohesion_forward
word_score["우크라이"].cohesion_forward
word_score["우크라이나"].cohesion_forward
#점점 확률이 올라가는 것을 확인

#1044번 기사 제목 명사 추출1
from soynlp.tokenizer import LTokenizer

scores = {word:score.cohesion_forward for word, score in word_score.items()}
l_tokenizer = LTokenizer(scores=scores)

l_tokenizer.tokenize(title[1044], flatten=False)

#1044번 기사 제목 명사 추출2
from soynlp.tokenizer import MaxScoreTokenizer

maxscore_tokenizer = MaxScoreTokenizer(scores=scores)
maxscore_tokenizer.tokenize(title[1044])
# Out:
# local variable 'f' referenced before assignment
# local variable 'f' referenced before assignment
# training was done. used memory 0.956 Gb
# all cohesion probabilities was computed. # words = 0
# all branching entropies was computed # words = 0
# all accessor variety was computed # words = 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22648/1610713196.py in <module>
#      17
#      18 #잘되는지 확인해보기
# ---> 19 word_score["검수완박"].cohesion_forward
#      20 word_score["우크라"].cohesion_forward
#      21 word_score["우크라이"].cohesion_forward
#
# KeyError: '검수완박'

# %%
strip_accents(title[33])
# Out:
# '\r\n\r\n\r\n\r\n\r\nSNS에 이틀 연속 당선인 비방윤석열 대통령 당선인(왼쪽 사진)과 조국 전 법무부 장관. 뉴시스 조국 전 법무부 장관이 윤석열 대통령 당선인을 향해 ‘살아있는 권력수사’를 본인에게도 적용하라며 연일 공세를 펴고 있다.조 전 장관은 11일 페이스북에 “‘윤석열 검찰’이 내건 ‘살아있는 권력수사’의 방식과 행태는 윤 (당선인) 자신과 가족, 윤 정부 인사에 대해 적용돼야 한다”고 적었다.조 전 장관의 지지자들은 해당 게시물에 “절대적으로 공감한다”는 식의 댓글을 달았다. 맛 칼럼니스트 황교익씨는 해당 글을 인용해 자신의 페이스북에 공유하기도 했다.조 전 장관은 전날에도 페이스북에 “조국 가족에 대한 ‘윤석열 잣대’를 (자신의) 가족과 윤 정부 인사에 적용하라”며 비슷한 취지의 주장을 올린 바 있다.조국 페이스북 캡처조 전 장관의 딸 조민씨가 고려대 환경생태공학부와 부산대 의학전문대학원(의전원)에서 잇달이 입학 취소 처분을 받은 것ᄀ
# ...

# %%
text=title[52]
clean_text(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14776/3877557574.py in <module>
# ----> 1 text=title[52]
#       2 clean_text(text)
#
# NameError: name 'title' is not defined

# %%
import re

def clean_text(text):
    text_rmv = re.sub('[-=+,#/\?:^.@*\"※%~∼ㆍ!【】』㈜©囹圄秋 ■◆◇▷▶◁◀ △▲▽▼<>‘|\(\)\[\]`\'…》→←↑↓↔〓♤♠♡♥♧♣⊙◈▣◐◑☆★\”\“\’·※~ ! @ # $ % ^ & * \ " ', ' ', text)
    text_rmv = ' '.join(text_rmv.split())
    return text_rmv

# %%
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# 문서 단위 말뭉치 생성 
corpus = DoublespaceLineCorpus("/content/4.12 news data.csv")
#앞 5개 문서 인쇄
i = 0
for d in corpus:
    print(i, d)
    i += 1
    if i > 4:
        break

word_extractor = WordExtractor()
word_extractor.train(corpus)

#잘되는지 확인해보기
word_score["검수완박"].cohesion_forward
word_score["우크라"].cohesion_forward
word_score["우크라이"].cohesion_forward
word_score["우크라이나"].cohesion_forward
#점점 확률이 올라가는 것을 확인

#1044번 기사 제목 명사 추출1
from soynlp.tokenizer import LTokenizer

scores = {word:score.cohesion_forward for word, score in word_score.items()}
l_tokenizer = LTokenizer(scores=scores)

l_tokenizer.tokenize(title[1044], flatten=False)

#1044번 기사 제목 명사 추출2
from soynlp.tokenizer import MaxScoreTokenizer

maxscore_tokenizer = MaxScoreTokenizer(scores=scores)
maxscore_tokenizer.tokenize(title[1044])
# Out:
# local variable 'f' referenced before assignment
# local variable 'f' referenced before assignment
# training was done. used memory 0.937 Gb
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22648/3783762166.py in <module>
#      16
#      17 #잘되는지 확인해보기
# ---> 18 word_score["검수완박"].cohesion_forward
#      19 word_score["우크라"].cohesion_forward
#      20 word_score["우크라이"].cohesion_forward
#
# NameError: name 'word_score' is not defined

# %%
words = []
for text in title:
    words += pc.stemmer(text)

print(words)
# Out:
# ['\r', '\n', '\r', '\n', '\r', '\n', '\r', '\n', '\r', '\n', '검', '수', '완', '박', '강', '행', '전', '국', '직', '걸', '고', '막', '겠다', '다', '보', '완', '수', '사', '요', '청', '도', '못', '해', '피', '해', '늘다', '국', '민', '에', '게', '개', '혁', '동', '의', '하', '지다', '만', '정', '치', '구', '호', '그', '만', '해', '야', '중', '대다', '범', '죄', '수', '사', '앞', '으', '로', '대다', '응', '무', '력', '해', '질', '것', '정', '치', '검', '찰', '특', '정', '목', '적', '수', '사', '어', '려', '운', '시', '스', '템', '방', '송', '라', '디', '오', '김', '현', '정', '의', '뉴', '스', '쇼', '진', '행', '김', '현', '정', '앵', '크다', '대다', '담', '김', '후', '곤', '대다', '구', '지다', '검', '장', '지다', '난', '해', '검', '경', '수', '사', '권', '조', '정', '안', '이', '통', '과', '되다', '면', '서다', '지다', '금', '검', '찰', '에', '게', '늘다', '여', '섯', '가다', '지다', '수', '사', '만', '하다', '수', '있다', '늘다', '권', '하다', '이', '남', '아', '있다', '습', '니', '다', '이', '른', '바', '대다', '중', '대다', '범', '죄', '죠', '부', '패', '범', '죄', '공', '직', '자', '범', '죄', '선', '거', '범', '죄', '방', '위', '산', '업', '범', '죄', '대다', '형', '차다', '사', '경
# ...

# %%
stop_words=set('/content/korean_stop_words.txt')
title = df.본문[5]
text = clean_text(title)

title1=[token for token in text if not token in stop_words]
print(title1)
# Out:
# ['검', '수', '완', '박', ' ', '강', '행', ' ', '전', '국', ' ', '檢', ' ', '직', ' ', '걸', '고', ' ', '막', '겠', '다', ' ', '보', '완', '수', '사', ' ', '요', '청', '도', ' ', '못', '해', ' ', '피', '해', '는', ' ', '국', '민', '에', '게', '檢', ' ', '개', '혁', ' ', '동', '의', '하', '지', '만', ' ', '정', '치', '구', '호', ' ', '그', '만', '해', '야', '중', '대', '범', '죄', ' ', '수', '사', ' ', '앞', '으', '로', ' ', '대', '응', ' ', '무', '력', '해', '질', ' ', '것', '정', '치', '검', '찰', ' ', '특', '정', '목', '적', ' ', '수', '사', ' ', '어', '려', '운', ' ', '시', '스', '템', ' ', '방', '송', ' ', 'C', 'B', 'S', ' ', '라', '디', '오', ' ', '김', '현', '정', '의', ' ', '뉴', '스', '쇼', ' ', 'F', 'M', ' ', '9', '8', ' ', '1', ' ', '0', '7', ' ', '2', '0', ' ', '0', '9', ' ', '0', '0', ' ', '진', '행', ' ', '김', '현', '정', ' ', '앵', '커', ' ', '대', '담', ' ', '김', '후', '곤', ' ', '대', '구', '지', '검', '장', ' ', '지', '난', '해', ' ', '검', '경', '수', '사', '권', ' ', '조', '정', '안', '이', ' ', '통', '과', '되', '면', '서', ' ', '지', '금', ' ', '검', '찰', '에', '게', '는', ' ', '여', '섯', ' 
# ...

# %%
len(words)
# Out:
# 11468

# %%
word_dict = pc.create_dic(words,100)

# %%
len(word_dict)
# Out:
# 3608

# %%
id2word = {i:word for word,i in word_dict.items()}

# %%
id2word
# Out:
# {1: '알 수 없음',
#  2: '에',
#  3: '하다',
#  4: '도',
#  5: '의',
#  6: '이',
#  7: '한',
#  8: '은',
#  9: '만',
#  10: '로',
#  11: '들',
#  12: '는',
#  13: '정부',
#  14: '가',
#  15: '되다',
#  16: '명',
#  17: '일',
#  18: '년',
#  19: '검',
#  20: '전',
#  21: '서',
#  22: '만에',
#  23: '수완',
#  24: '안',
#  25: '크다',
#  26: '박',
#  27: '적',
#  28: '이은해',
#  29: '날씨',
#  30: '대다',
#  31: '한국',
#  32: '장',
#  33: '금리',
#  34: '과',
#  35: '월',
#  36: '으로',
#  37: '없다',
#  38: '것',
#  39: '있다',
#  40: '우',
#  41: '다',
#  42: '비',
#  43: '검토',
#  44: '엔',
#  45: '대',
#  46: '중',
#  47: '투자',
#  48: '키',
#  49: '오늘',
#  50: '자',
#  51: '하락',
#  52: '주택',
#  53: '부터',
#  54: '억',
#  55: '와',
#  56: '삼성',
#  57: '원',
#  58: '지원',
#  59: '조',
#  60: '해제',
#  61: '러시아',
#  62: '첫',
#  63: '주',
#  64: '속',
#  65: '만원',
#  66: '뉴스',
#  67: '세',
#  68: '단독',
#  69: '젤',
#  70: '렌스',
#  71: '러',
#  72: '목표',
#  73: '진화',
#  74: '윤석열',
#  75: '마스크',
#  76: '더',
#  77: '인수위',
#  78: '양',
#  79: '화',
#  80: '고',
# ...

# %%
id2word[3000]
# Out:
# '베이커리'

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

def int_encoding(df):
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(df['과일'])
  word_dict = tokenizer.word_index

  return word_dict

int_encoding(title[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9896/162070337.py in <module>
#       8   return word_dict
#       9
# ---> 10 int_encoding(title[1])
#
# ~\AppData\Local\Temp/ipykernel_9896/162070337.py in int_encoding(df)
#       3 def int_encoding(df):
#       4   tokenizer = Tokenizer()
# ----> 5   tokenizer.fit_on_texts(df['과일'])
#       6   word_dict = tokenizer.word_index
#       7
#
# TypeError: string indices must be integers

# %%
def padding(df):
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(df['과일'])
  encoded = tokenizer.texts_to_sequences(df['과일']) # 뒤에 설정 넣을 수 있음(아래로)

  return encoded

# %%
texts = []
for text in title:
    tt = pc.stemmer(text)
    texts.append(tt)

print(texts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10784/2073033300.py in <module>
#       1 texts = []
# ----> 2 for text in title:
#       3     tt = pc.stemmer(text)
#       4     texts.append(tt)
#       5
#
# NameError: name 'title' is not defined

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
encoded = tokenizer.texts_to_sequences(texts)

encoded
# Out:
# [[1637, 1638, 18, 22, 25, 164, 1, 1035, 1036, 26, 1639, 366, 1640],
#  [67, 1641, 1642, 1037, 165, 1643, 1644, 1038, 1645, 1646, 1647, 1039],
#  [184, 166, 1040, 6, 68, 69, 47, 1648, 30, 448],
#  [563, 449, 367, 738, 739, 210, 5, 450, 18, 22, 1649, 88, 1650],
#  [451, 1651, 452, 89, 1041, 1042, 13, 1043, 90, 36],
#  [740, 1044, 368, 91, 741, 453, 742, 743],
#  [58, 1652, 1045, 564, 454, 6, 18, 22, 25, 1653, 565, 1046, 369, 1654, 185],
#  [186, 92, 744, 4, 1047, 187, 112, 745, 1048, 33, 244, 1, 455, 167, 288],
#  [1049, 186, 1, 1655, 14, 140, 1656, 73, 4, 1050, 370],
#  [1657, 1658, 1659, 120, 1051, 566, 1660, 4, 368, 26, 456, 11, 1661, 140],
#  [67,
#   1662,
#   1663,
#   1052,
#   746,
#   6,
#   1664,
#   19,
#   1665,
#   1666,
#   1053,
#   1054,
#   168,
#   245,
#   457,
#   2,
#   289,
#   458],
#  [12, 1667, 1041, 371, 1668, 141, 12, 11, 91, 371],
#  [169, 12, 211, 290, 291, 292, 6, 59, 42, 34, 43, 567, 74, 59],
# ...

# %%
title
# Out:
# 0       김준일 대표, ‘검수완박’ 민주당에 쓴소리…“‘논리적 확증편향’ 빠졌는지 돌아봐야”
# 1                   [단독]윤희숙 父 ‘투기의혹’ 세종시 땅 매각…차익 전액 기부
# 2                           전쟁 피해 절박한 젤렌스키… 미지근한 한국 국회
# 3               금태섭 "文 정권 땐 특수부 키우더니 이젠 검수완박…이러니 내로남불"
# 4                     송영길 "애도 아니고 5선 정치인 진퇴가 가벼울 수 없다"
#                              ...
# 1042                     친(親)러 도네츠크 군, “우크라 마리우폴 항 장악”
# 1043                      러시아군 물러났지만...현실화된 우크라발 식량 위기
# 1044                     우크라 內 친러 도네츠크 군대 "마리우폴 장악 임박"
# 1045               은혜 갚은 빈살만?…사우디 국부펀드, 쿠슈너에 2조5천억원 투자
# 1046                  마크롱, 우크라 올인한 사이…르펜, 먹고사는 문제로 맹추격
# Name: 기사제목, Length: 1046, dtype: object

# %%
from NewsAnalyzer.PreProcesser import preprocesser

pc = preprocesser()

file_path = "data/2022-04-12 news data, test.csv"
df = pc.road_data(file_path)
title = df["기사제목"]
encoded_title = pc.preprocess(title)
encoded_title
# Out:
# array([[1637, 1638,   18, ...,    0,    0,    0],
#        [  67, 1641, 1642, ...,    0,    0,    0],
#        [ 184,  166, 1040, ...,    0,    0,    0],
#        ...,
#        [  39,   24,  432, ...,    0,    0,    0],
#        [3597, 3598, 3599, ...,    0,    0,    0],
#        [ 736, 1033,   39, ...,    0,    0,    0]])

# %%
news = df["본문"]
encoded = pc.preprocess(news)
encoded
# Out:
# array([[  66,  809,  939, ...,    0,    0,    0],
#        [2699,   75,   33, ...,    0,    0,    0],
#        [  66,  406,  402, ...,    0,    0,    0],
#        ...,
#        [  66, 1315,   73, ...,    0,    0,    0],
#        [ 981,  453,   60, ...,    0,    0,    0],
#        [4164, 4467, 1844, ...,    0,    0,    0]])

# %%
print(len(encoded[0]))
print(len(encoded_title[0]))
# Out:
# 3530
# 23

# %%
from kiwipiepy import Kiwi, Match
from kiwipiepy.utils import Stopwords

def noun_extractor(sentence):
    kiwi = Kiwi()
    stop_words_file = open("data/korean_stop_words.txt","r",encoding='utf-8')
    stop_words_list=[]
    for line in stop_words_file.readlines():
        stop_words_list.append(line.rstrip())
    stop_words_file.close()
    result_iter = kiwi.tokenize(sentence, normalize_coda=True)
    i = 0
    for i in range(len(result_iter)):
        if result_iter[i][1] == 'NNG':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NNP':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NR':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NP':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'SL':
            print (result_iter[i][0])
    nouns=[i for i in sentence if not i in stop_words_list]
    print(nouns)

# %%
from kiwipiepy import Kiwi, Match
import re

def clean_text(title):
    text_rmv = re.sub('[-=+,#/\?:^.@*\"※%~∼ㆍ!【】』㈜©囹圄秋 ■◆◇▷▶◁◀ △▲▽▼<>‘|\(\)\[\]`\'…》→←↑↓↔〓♤♠♡♥♧♣⊙◈▣◐◑☆★\”\“\’·※~ ! @ # $ % ^ & * \ " ]', ' ', title)
    text_rmv = ' '.join(text_rmv.split())
    return text_rmv

def rmv_stopwords(text_rmv):
    i=0
    stop_words_file = open("data/korean_stop_words.txt","r",encoding='utf-8')
    stop_words_list=[]
    clean_words_list=[]
    for line in stop_words_file.readlines():
        stop_words_list.append(line.rstrip())
        stop_words_file.close()
    for words in text_rmv:
        for i in range(len(text_rmv)):
            if words not in stop_words_list:
                words = words[ i += 1]
                clean_words_list.append(words)
                return(words)

def noun_extractor(words):
    kiwi = Kiwi()
    result_iter = kiwi.tokenize(words, normalize_coda=True)
    i = 0
    for i in range(len(result_iter)):
        if result_iter[i][1] == 'NNG':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NNP':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NR':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NP':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'SL':
            print (result_iter[i][0])
    return str(i)
# Out:
#   File "C:\Users\서지혜\AppData\Local\Temp/ipykernel_30216/1559262009.py", line 20
#     words = words[ i += 1]
#                      ^
# SyntaxError: invalid syntax

# %%
title = df.본문[5]
text_rmv = clean_text(title)
rmv_stopwords(text_rmv)
# Out:
# '검'

# %%
def rmv_stopwords(text_rmv):
    stop_words_file = open("data/korean_stop_words.txt","r",encoding='utf-8')
    stop_words_list=[]
    clean_words_list=[]
    for line in stop_words_file.readlines():
        stop_words_list.append(line.rstrip())
        stop_words_file.close()
    for words in range(text_rmv):
        if words not in stop_words_list:
          clean_words.append(i)
        return(words)

# %%
rmv_stopwords(text_rmv)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30216/961776546.py in <module>
# ----> 1 rmv_stopwords(text_rmv)
#
# ~\AppData\Local\Temp/ipykernel_30216/90452909.py in rmv_stopwords(text_rmv)
#       6         stop_words_list.append(line.rstrip())
#       7         stop_words_file.close()
# ----> 8     for words in range(text_rmv):
#       9         if words not in stop_words_list:
#      10           clean_words.append(i)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
from kiwipiepy import Kiwi, Match
title = df.본문[5]
sentence = clean_text(title)
noun_extractor(sentence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30216/2408768676.py in <module>
#       1 from kiwipiepy import Kiwi, Match
#       2 title = df.본문[5]
# ----> 3 sentence = clean_text(title)
#       4 noun_extractor(sentence)
#
# NameError: name 'clean_text' is not defined

# %%
title = df.본문[5]
noun_extractor(sentence)
print(type(noun_extractor(sentence)))
# Out:
# 검수완
# 박
# 강행
# 전국
# 직
# 보완
# 수사
# 요청
# 피해
# 국민
# 개혁
# 동의
# 정치
# 구호
# 중대
# 범죄
# 수사
# 앞
# 대응
# 무력
# 정치
# 검찰
# 특정
# 목적
# 수사
# 시스템
# 방송
# CBS
# 라디오
# 김현정
# 뉴스쇼
# FM
# 진행
# 김현정
# 앵커
# 대담
# 김후
# 대구
# 지검장
# 검경
# 수사
# 조정안
# 통과
# 검찰
# 여섯
# 수사
# 권한
# 대
# 중대
# 범죄
# 부패
# 범죄
# 공직자
# 범죄
# 선거범죄
# 방위
# 산업
# 범죄
# 대
# 참사
# 경제
# 범죄
# 수사
# 기소
# 권한
# 조직
# 완성
# 이것
# 검수완
# 박
# 민주당
# 문재인
# 정권
# 이것
# 분위기
# 당론
# 확정
# 이
# 검찰
# 법무부
# 반발
# 박범계
# 법무부
# 장관
# 제외
# 의견
# 일치
# 정도
# 상황
# 김
# 오수
# 검찰
# 총장
# 직
# 중요
# 문제
# 여러분
# 양쪽
# 이야기
# 여러분
# 생각
# 정리
# 기회
# 양쪽
# 저
# 반대
# 입장
# 질문
# 논지
# 인터뷰
# 어제
# 전국
# 지검장
# 회의
# 참석
# 김후
# 대구
# 지검장
# 연결
# 민주당
# 윤호중
# 비대위원장
# 연결
# 김
# 후
# 대구
# 지검장
# 김후
# 검사장
# 김후
# 안녕
# 김
# 후
# 검사장
# 김현정
# 전국
# 지검장
# 김후
# 김현정
# 마라톤
# 회의
# 분위기
# 김후
# 대구
# 지검장
# 오전
# 서울
# 서초구
# 검찰청
# 전국
# 지검장
# 회의
# 참석
# 취재진
# 질의
# 답변
# 박종민
# 기자
# 김후
# 저희
# 법안
# 추진
# 신중
# 검토
# 필요
# 일치
# 입장
# 김현정
# 신중하
# 검토
# 필요
# 중요
# 질문
# 김후
# 김현정
# 검수
# 박
# 반대
# 김후
# 저희
# 검찰
# 개
# 혁
# 문제
# 국민
# 여러분
# 심려
# 마음
# 저희
# 국민
# 신뢰
# 법안
# 추진
# ...

# %%
title = df.본문[5]
sentence = clean_text(title)
nouns = noun_extractor(sentence)
delete_stop_words(nouns)
# Out:
# 검수완
# 박
# 강행
# 전국
# 직
# 보완
# 수사
# 요청
# 피해
# 국민
# 개혁
# 동의
# 정치
# 구호
# 중대
# 범죄
# 수사
# 앞
# 대응
# 무력
# 정치
# 검찰
# 특정
# 목적
# 수사
# 시스템
# 방송
# CBS
# 라디오
# 김현정
# 뉴스쇼
# FM
# 진행
# 김현정
# 앵커
# 대담
# 김후
# 대구
# 지검장
# 검경
# 수사
# 조정안
# 통과
# 검찰
# 여섯
# 수사
# 권한
# 대
# 중대
# 범죄
# 부패
# 범죄
# 공직자
# 범죄
# 선거범죄
# 방위
# 산업
# 범죄
# 대
# 참사
# 경제
# 범죄
# 수사
# 기소
# 권한
# 조직
# 완성
# 이것
# 검수완
# 박
# 민주당
# 문재인
# 정권
# 이것
# 분위기
# 당론
# 확정
# 이
# 검찰
# 법무부
# 반발
# 박범계
# 법무부
# 장관
# 제외
# 의견
# 일치
# 정도
# 상황
# 김
# 오수
# 검찰
# 총장
# 직
# 중요
# 문제
# 여러분
# 양쪽
# 이야기
# 여러분
# 생각
# 정리
# 기회
# 양쪽
# 저
# 반대
# 입장
# 질문
# 논지
# 인터뷰
# 어제
# 전국
# 지검장
# 회의
# 참석
# 김후
# 대구
# 지검장
# 연결
# 민주당
# 윤호중
# 비대위원장
# 연결
# 김
# 후
# 대구
# 지검장
# 김후
# 검사장
# 김후
# 안녕
# 김
# 후
# 검사장
# 김현정
# 전국
# 지검장
# 김후
# 김현정
# 마라톤
# 회의
# 분위기
# 김후
# 대구
# 지검장
# 오전
# 서울
# 서초구
# 검찰청
# 전국
# 지검장
# 회의
# 참석
# 취재진
# 질의
# 답변
# 박종민
# 기자
# 김후
# 저희
# 법안
# 추진
# 신중
# 검토
# 필요
# 일치
# 입장
# 김현정
# 신중하
# 검토
# 필요
# 중요
# 질문
# 김후
# 김현정
# 검수
# 박
# 반대
# 김후
# 저희
# 검찰
# 개
# 혁
# 문제
# 국민
# 여러분
# 심려
# 마음
# 저희
# 국민
# 신뢰
# 법안
# 추진
# ...

# %%
stop_words_file = open("data/korean_stop_words.txt","r",encoding='utf-8')
stop_words_list=[]
clean_words_list=[]
for line in stop_words_file.readlines():
     stop_words_list.append(line.rstrip())
stop_words_file.close()
for i in noun_extractor(sentence):
     if i not in stop_words_list:
          clean_words.append(i)
print(clean_words)
# Out:
# 검수완
# 박
# 강행
# 전국
# 직
# 보완
# 수사
# 요청
# 피해
# 국민
# 개혁
# 동의
# 정치
# 구호
# 중대
# 범죄
# 수사
# 앞
# 대응
# 무력
# 정치
# 검찰
# 특정
# 목적
# 수사
# 시스템
# 방송
# CBS
# 라디오
# 김현정
# 뉴스쇼
# FM
# 진행
# 김현정
# 앵커
# 대담
# 김후
# 대구
# 지검장
# 검경
# 수사
# 조정안
# 통과
# 검찰
# 여섯
# 수사
# 권한
# 대
# 중대
# 범죄
# 부패
# 범죄
# 공직자
# 범죄
# 선거범죄
# 방위
# 산업
# 범죄
# 대
# 참사
# 경제
# 범죄
# 수사
# 기소
# 권한
# 조직
# 완성
# 이것
# 검수완
# 박
# 민주당
# 문재인
# 정권
# 이것
# 분위기
# 당론
# 확정
# 이
# 검찰
# 법무부
# 반발
# 박범계
# 법무부
# 장관
# 제외
# 의견
# 일치
# 정도
# 상황
# 김
# 오수
# 검찰
# 총장
# 직
# 중요
# 문제
# 여러분
# 양쪽
# 이야기
# 여러분
# 생각
# 정리
# 기회
# 양쪽
# 저
# 반대
# 입장
# 질문
# 논지
# 인터뷰
# 어제
# 전국
# 지검장
# 회의
# 참석
# 김후
# 대구
# 지검장
# 연결
# 민주당
# 윤호중
# 비대위원장
# 연결
# 김
# 후
# 대구
# 지검장
# 김후
# 검사장
# 김후
# 안녕
# 김
# 후
# 검사장
# 김현정
# 전국
# 지검장
# 김후
# 김현정
# 마라톤
# 회의
# 분위기
# 김후
# 대구
# 지검장
# 오전
# 서울
# 서초구
# 검찰청
# 전국
# 지검장
# 회의
# 참석
# 취재진
# 질의
# 답변
# 박종민
# 기자
# 김후
# 저희
# 법안
# 추진
# 신중
# 검토
# 필요
# 일치
# 입장
# 김현정
# 신중하
# 검토
# 필요
# 중요
# 질문
# 김후
# 김현정
# 검수
# 박
# 반대
# 김후
# 저희
# 검찰
# 개
# 혁
# 문제
# 국민
# 여러분
# 심려
# 마음
# 저희
# 국민
# 신뢰
# 법안
# 추진
# ...

# %%
def stop_words_list(words):
    stopwords
    stopwords.add(('단독', 'NNG'))
    stopwords.add(('자료', 'NNG'))
    stopwords.add(('사진', 'NNG'))
    stopwords.add(('기자', 'NNG'))
    stopwords.add(('동영상', 'NNG'))
    stopwords.add(('이미지', 'NNG'))
    stopwords.add(('출처', 'NNG'))
    stopwords.add(('뉴스', 'NNG'))
    stopwords.add(('카카오톡', 'NNG'))
    stopwords.add(('news', 'SL'))
    stopwords.add(('co', 'SL'))
    stopwords.add(('kr', 'SL'))
    stopwords.add(('org', 'SL'))
    stopwords.add(('naver', 'SL'))
    stopwords.add(('kmib', 'SL'))
    stopwords.add(('CBS', 'SL'))
    stopwords.add(('yna', 'SL'))
    return stopwords

# %%
from konlpy.tag import Okt
from soynlp.tokenizer import MaxScoreTokenizer

def stemmer(text):
    text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]","",text)
    okt = Okt()
    maxscore_tokenizer = MaxScoreTokenizer(scores=scores)
    text = maxscore_tokenizer.tokenize(text)#okt.morphs(text, stem= True)
    return text
    
def remove_stop_words(text):
    word_token = stemmer(text)
    stop_words = pd.read_csv("./korean_stop_words.txt")
    result = [word for word in word_token if not word in stop_words]
    return result

#결과확인
remove_stop_words(title[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30216/3878612618.py in <module>
#      16
#      17 #결과확인
# ---> 18 remove_stop_words(title[2])
#
# ~\AppData\Local\Temp/ipykernel_30216/3878612618.py in remove_stop_words(text)
#      10
#      11 def remove_stop_words(text):
# ---> 12     word_token = stemmer(text)
#      13     stop_words = pd.read_csv("./korean_stop_words.txt")
#      14     result = [word for word in word_token if not word in stop_words]
#
# ~\AppData\Local\Temp/ipykernel_30216/3878612618.py in stemmer(text)
#       5     text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]","",text)
#       6     okt = Okt()
# ----> 7     maxscore_tokenizer = MaxScoreTokenizer(scores=scores)
#       8     text = maxscore_tokenizer.tokenize(text)#okt.morphs(text, stem= True)
#       9     return text
#
# NameError: name 'scores' is not defined

# %%
stop_words_file = open("data/korean_stop_words.txt","r",encoding='utf-8')
stop_words_list=[]
for line in stop_words_file.readlines():
    stop_words_list.append(line.rstrip())
stop_words_file.close()
print(stop_words_list)

noun_extractor(sentence)
search = "stop_words_list"
for word in word_list:
    if search in word: 
        print('>> remove: ' + word)
        word_list.remove(word)
        
print(word_list)
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라', '의해', '을', '를', '에', '의', '가', '으로', '로', '에게', '뿐이다', '의거하여', '근거하여', '입각하여', '기준으로', '예하면', '예를 들면', '예를 들자면', '저', '소인', '소생', '저희', '지말고', '하지마', '하지마라', '다른', '물론', '또한', '그리고', '비길수 없다', '해서는 안된다', '뿐만 아니라', '만이 아니다', '만은 아니다', '막론하고', '관계없이', '그치지 않다', '그러나', '그런데', '하지만', '든간에', '논하지 않다', '따지지 않다', '설사', '비록', '더라도', '아니면', '만 못하다', '하는 편이 낫다', '불문하고', '향하여', '향해서', '향하다', '쪽으로', '틈타', '이용하여', '타다', '오르다', '제외하고', '이 외에', '이 밖에', '하여야', '비로소', '한다면 몰라도', '외에도', '이곳', '여기', '부터', '기점으로', '따라서', '할 생각이다', '하려고하다', '이리하여', '그리하여', '그렇게 함으로써', '하지만', '일때', '할때', '앞에서', '중에서', '보는데서', '으로써', '로써', '까지', '해야한다', '일것이다', '반드시', '할줄알다', '할수있다', '할수있어', '임에 틀림없다', '한다면', '등', '등등', '제', '겨우', '단지', '다만', '할뿐', '딩동', '댕그', '대해서', '대하여', '대하면', '훨씬', '얼마나', '얼마만큼', '얼마큼', '남짓', '여', '얼마간', '약간', '다소', '좀', '조금', '다수', '몇', '얼마', '지만', '하물며', '또한', '그러나', '그렇지만', '하지만', '이외에도', '대해 말하자면', '뿐이다', '다음에', '반대로', '반대로 말하자면', '이와 반대로
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
example = "Family is not an important thing. It's everything."
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(example)
result = []
for w in word_tokens:
    if w not in stop_words:
        result.append(w)
print(word_tokens)
'Family', 'is', 'not', 'an', 'important', 'thing', '.', 'It', "'s", 'everything', '.']
print(result)
['Family', 'important', 'thing', '.', 'It', "'s", 'everything', '.']

# %%
from kiwipiepy import Kiwi, Match

def noun_extractor(sentence):
    kiwi = Kiwi()
    kiwi.add_user_word('내로남불', 'NNP', 0)
    kiwi.add_user_word('검수완박', 'NNP', 0)
    result_iter = kiwi.tokenize(sentence, normalize_coda=True)
    i = 0
    for i in range(len(result_iter)):
        if result_iter[i][1] == 'NNG':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NNP':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NR':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'NP':
            print (result_iter[i][0])
        elif result_iter[i][1] == 'SL':
            print (result_iter[i][0])
    return str(i)

# %%
from soynlp.tokenizer import LTokenizer
from soynlp.tokenizer import MaxScoreTokenizer
word_extractor = WordExtractor()
word_extractor.train(corpus)
word_score = word_extractor.extract()
word_extractor = WordExtractor()
word_extractor.train(corpus)
word_score = word_extractor.extract()
LTokenizer(scores=scores)



def stemmer(text):
    text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]","",text)
    okt = Okt()
    word_extractor = WordExtractor()
    word_extractor.train(corpus)
    word_score = word_extractor.extract(
    maxscore_tokenizer = MaxScoreTokenizer(scores=scores)
    return text
    
def remove_stop_words(text):
    text = maxscore_tokenizer.tokenize(text)#okt.morphs(text, stem= True)
    word_token = stemmer(text)
    stop_words = pd.read_csv("./korean_stop_words.txt")
    result = [word for word in word_token if not word in stop_words]
    return result

#결과확인
remove_stop_words(title[2])
# Out:
#   File "C:\Users\서지혜\AppData\Local\Temp/ipykernel_30216/2429154922.py", line 20
#     return text
#     ^
# SyntaxError: invalid syntax
