# %%
from NewsAnalyzer.Analyzer import analysis
from NewsAnalyzer.PreProcesser import preprocesser

pp = preprocesser()

file_path = "data/2022-04-18 news data.csv"

df = pp.load_data(file_path)

# 카테고리 : 정치, 경제, 사회, 생활, IT, 세계
df
# Out:
#      카테고리   언론사                                    기사제목           날짜  \
# 0      정치   SBS  [단독] '6억 집을 1억에'…이창용 한은 총재 후보자 다운계약 의혹  2022.04.18.
# 1      정치  중앙일보         노정희 선관위원장, '소쿠리 대선' 논란 44일만에 사퇴  2022.04.18.
# 2      정치   YTN             단거리 발사에 김정은 참석...전술핵 탑재 노렸나  2022.04.18.
# 3      정치  서울경제      장제원 "조작? 위조?…정호영, 조국과 뭐가 같나 얘기해보라"  2022.04.18.
# 4      정치  연합뉴스     국민의힘·국민의당, 합당 공식 선언…"공동정부 초석"(종합2보)  2022.04.18.
# ...   ...   ...                                     ...          ...
# 4641   세계  국제신문       전 세계 물가 폭등 아우성…30년만에 ‘大인플레’ 시대 진입  2022.04.18.
# 4642   세계  국민일보        물·전기 없이 13만명 ‘절망의 항전’… 마리우폴 ‘참극’  2022.04.18.
# 4643   세계  중앙일보         러 “마리우폴 함락” 주장…우크라 “방어군 버티고 있다”  2022.04.18.
# 4644   세계  중앙일보           침몰한 러의 자존심…미 “푸틴, 핵 쓸 가능성 커져”  2022.04.18.
# 4645   세계  조선일보             [최유식의 온차이나] 쑹산 소림사의 ‘쿵후 경영’  2022.04.18.
#
#                                                      본문  \
# 0     \n\n\n\n\n이창용 한국은행 총재 후보자가 지난 2002년, 서울 중구 신당동...
# 1     \n\n\n\n\n\t\n\t  노정희 중앙선거관리위원회위원장이 18일 사의를 표명...
# 2     \n\n\n\n동영상 뉴스\n\n\n\n\n\t\n\t[앵커]김정은 국무위원장이 단...
# 3     \n\n\n\n\n장제원 대통령 당선인 비서실장이 지난 17일 서울 종로구 통의동 ...
# 4     \n\n\n\n\n6·1 지방선거 단일 공천…당대표 이준석, 최고위원 2명 국민의당...
# ...                                                 ...
# 4641  \n\n\n\n\nOECD 2월 상승률 7.7% 급등- 우크라發 에너지가격 큰 폭 ...
# 4642  \n\n\n\n\n초토화 작전에 건물 90% 이상 파괴우크라군 최악 포위전 속 결사...
# 4643  \n\n\n\n\n  우크라이나 동남부 돈바스 지역에서 친러 분리주의 무장대원들이 ...
# 4644  \n\n\n\n\n\t\n\t  지난 14일 러시아 해군 흑해함대의 기함인 모스크바...
# 4645  \n\n\n\n\n스융신 방장, 16개 자회사 거느린 ‘상업 제국’ 구축국유기업과 ...
#
#                                                    기사링크
# 0     https://news.naver.com//main/read.naver?mode=L...
# 1     https://news.naver.com//main/read.naver?mode=L...
# 2     https://news.naver.com//main/read.naver?mode=L...
# 3     https://news.naver.com//main/read.naver?mode=L...
# 4     https://news.naver.com//main/read.naver?mode=L...
# ...                                                 ...
# 4641  https://news.naver.com//main/read.naver?mode=L...
# 4642  https://news.naver.com//main/read.naver?mode=L...
# 4643  https://news.naver.com//main/read.naver?mode=L...
# 4644  https://news.naver.com//main/read.naver?mode=L...
# 4645  https://news.naver.com//main/read.naver?mode=L...
#
# [4645 rows x 6 columns]
